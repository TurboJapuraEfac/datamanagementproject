# %%
import os
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import re
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()

# %%
hopeless_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka.csv',  sep='\t')
hopeless_tweets_df.head()
# Out:
#                     id      conversation_id  \
# 0  1314463232799563776  1314463232799563776
# 1  1240137433057984512  1240137433057984512
# 2  1238694003874422784  1238694003874422784
# 3  1226173869117071360  1226173869117071360
# 4   566255648091152384   566255648091152384
#
#                                     created_at        date      time  \
# 0  2020-10-09 12:40:30 Sri Lanka Standard Time  2020-10-09  12:40:30
# 1  2020-03-18 10:16:19 Sri Lanka Standard Time  2020-03-18  10:16:19
# 2  2020-03-14 10:40:39 Sri Lanka Standard Time  2020-03-14  10:40:39
# 3  2020-02-08 21:30:06 Sri Lanka Standard Time  2020-02-08  21:30:06
# 4  2015-02-13 20:50:41 Sri Lanka Standard Time  2015-02-13  20:50:41
#
#    timezone              user_id         username                       name  \
# 0       530           3112391544     vishwamadu92          Vishwa Gunarathna
# 1       530  1206122519209619456  abishekchathura           Chathura Abishek
# ...

# %%
hopeless_tweets_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
hopeless_tweets_df.head()
# Out:
#                     id      time  \
# 0  1314463232799563776  12:40:30
# 1  1240137433057984512  10:16:19
# 2  1238694003874422784  10:40:39
# 3  1226173869117071360  21:30:06
# 4   566255648091152384  20:50:41
#
#                                                tweet language  \
# 0  Corona season comming soon!!!!! @ Union Place ...       en
# 1  Corona Holidays be like 👀  https://t.co/mBo1FY...       en
# 2  The_beginning_of_corona_vacation ;-) 😁 On_the_...       en
# 3  අවදානමට පෙර සූදානම 😔 #Coronavius #corona #lka ...       si
# 4  Drinking Corona! Hell Yeah! #Corona #FeelingGr...       en
#
#                                            hashtags cashtags  \
# 0                                                []       []
# 1                                                []       []
# 2                                                []       []
# 3       ['coronavius', 'corona', 'lka', 'srilanka']       []
# 4  ['corona', 'feelinggreat', 'keg', 'bestbuddies']       []
#
# ...

# %%
sl0_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka.csv',  sep='\t')
sl1_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka1.csv',  sep='\t')
sl2_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka2.csv',  sep='\t')
sl3_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka3.csv',  sep='\t')
sl4_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka4.csv',  sep='\t')
sl5_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka5.csv',  sep='\t')
sl6_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka6.csv',  sep='\t')
sl7_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka7.csv',  sep='\t')
sl8_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka8.csv',  sep='\t')
sl9_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka9.csv',  sep='\t')
sl10_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka10.csv',  sep='\t')
sl11_tweets_df = pd.read_csv('E:/Project 5 credits/new/Sri Lanka/srilanka11.csv',  sep='\t')


df_row_reindex = pd.concat([sl0_tweets_df,sl1_tweets_df,sl2_tweets_df,sl3_tweets_df,sl4_tweets_df,sl5_tweets_df,sl6_tweets_df,sl7_tweets_df,sl8_tweets_df,sl9_tweets_df,sl10_tweets_df,sl11_tweets_df], ignore_index=True)

df_row_reindex
# Out:
#                        id      conversation_id  \
# 0     1314463232799563776  1314463232799563776
# 1     1240137433057984512  1240137433057984512
# 2     1238694003874422784  1238694003874422784
# 3     1226173869117071360  1226173869117071360
# 4      566255648091152384   566255648091152384
# ...                   ...                  ...
# 1711  1351413865716854784  1351413865716854784
# 1712  1351387958180384768  1351387958180384768
# 1713  1351368602302124035  1351368602302124035
# 1714  1351226918742458373  1351226918742458373
# 1715  1316032629259431936  1315994891898454016
#
#                                        created_at        date      time  \
# 0     2020-10-09 12:40:30 Sri Lanka Standard Time  2020-10-09  12:40:30
# 1     2020-03-18 10:16:19 Sri Lanka Standard Time  2020-03-18  10:16:19
# 2     2020-03-14 10:40:39 Sri Lanka Standard Time  2020-03-14  10:40:39
# 3     2020-02-08 21:30:06 Sri Lanka Standard Time  2020-02-08  21:30:06
# ...

# %%
df_row_reindex.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
df_row_reindex.head()
# Out:
#                     id      time  \
# 0  1314463232799563776  12:40:30
# 1  1240137433057984512  10:16:19
# 2  1238694003874422784  10:40:39
# 3  1226173869117071360  21:30:06
# 4   566255648091152384  20:50:41
#
#                                                tweet language  \
# 0  Corona season comming soon!!!!! @ Union Place ...       en
# 1  Corona Holidays be like 👀  https://t.co/mBo1FY...       en
# 2  The_beginning_of_corona_vacation ;-) 😁 On_the_...       en
# 3  අවදානමට පෙර සූදානම 😔 #Coronavius #corona #lka ...       si
# 4  Drinking Corona! Hell Yeah! #Corona #FeelingGr...       en
#
#                                            hashtags cashtags  \
# 0                                                []       []
# 1                                                []       []
# 2                                                []       []
# 3       ['coronavius', 'corona', 'lka', 'srilanka']       []
# 4  ['corona', 'feelinggreat', 'keg', 'bestbuddies']       []
#
# ...

# %%
depressive_twint_tweets_df = df_row_reindex.drop_duplicates()
export_csv = depressive_twint_tweets_df.to_csv(r'depressive_unigram_tweets_final.csv')
